# %%
import jax
import jax.numpy as jnp
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import numpyro
import numpyro.distributions as dist
from numpyro.distributions.constraints import real
import pandas as pd

import pollux as plx
from pollux.models.transforms import LinearTransform

from process_rvs import process_spectra

jax.config.update("jax_enable_x64", True)

from matplotlib import rcParams

params = {
   'axes.labelsize': 15,
   'font.size': 15,
   'legend.fontsize': 14,
   'xtick.minor.visible': True,
   'ytick.minor.visible': True,
   'xtick.labelsize': 15,
   'ytick.labelsize': 15,
   'text.usetex': True, #to use TeX in your labels
   'font.family':'serif',
   'axes.titlesize': 15,
   'xtick.direction': 'in',
   'ytick.direction': 'in',
   'xtick.top': True,
   'ytick.right': True,
   'xtick.major.size': 6,
   'xtick.minor.size': 3,
   'ytick.major.size': 6,
   'ytick.minor.size': 3
   }
rcParams.update(params)

# %% [markdown]
# # Getting the data ready

# %%
df_stars = pd.read_pickle('../data/giants_feb25.pkl')
df_stars = df_stars.head(500)

# %%
df_stars.head()
# Out:
#              source_id                                               flux  \
# 0  4664665578195665280  [--, --, 0.9704861, 0.97988486, 0.97052944, 0....
# 1   635141004978813952  [0.9757919, 0.97522444, 0.9785527, 0.9825248, ...
# 2  3860052551055446016  [0.98625946, 0.98520243, 0.9877424, 0.9980393,...
# 4  2636938705167778688  [0.97965676, 0.96631527, 0.95401424, 0.947494,...
# 5  3828309787800526848  [0.98253953, 0.9740644, 0.97302127, 0.98223245...
#
#                                           flux_error         teff  e_teff  \
# 0  [--, --, 0.01576104, 0.00933747, 0.006561436, ...  4707.933105   3.487
# 1  [0.006786422, 0.005791272, 0.0050528045, 0.004...  4799.769043   2.879
# 2  [0.012515559, 0.011487071, 0.011218716, 0.0112...  4843.961914   4.595
# 4  [0.011526696, 0.011534087, 0.007806127, 0.0074...  4527.612793   1.660
# 5  [0.008798221, 0.009388227, 0.0098934015, 0.008...  4741.166992   3.556
#
#     logg  e_logg       j-h  e_j-h    h-k  ...   si_h    e_si_h   fe_h  e_fe_h  \
# 0  2.450   0.008  0.551001  0.025  0.068  ... -0.104  0.002236 -0.344   0.001
# 1  2.742   0.005  0.467000  0.027  0.134  ...  0.011  0.002236 -0.035   0.001
# 2  2.584   0.009  0.555000  0.045  0.063  ... -0.181  0.002828 -0.241   0.001
# 4  2.719   0.004  0.567000  0.031  0.119  ...  0.032  0.001414 -0.012   0.001
# 5  2.811   0.007  0.505000  0.023  0.092  ... -0.217  0.002828 -0.256   0.001
#
#     ni_h  e_ni_h   ca_h    e_ca_h   ce_h  e_ce_h
# 0 -0.185   0.001 -0.174  0.002236 -0.416   0.001
# 1 -0.054   0.001  0.028  0.002236 -0.070   0.001
# 2 -0.278   0.001 -0.209  0.002828 -0.172   0.001
# 4 -0.008   0.001  0.027  0.001414 -0.150   0.001
# 5 -0.230   0.001 -0.163  0.002828 -0.292   0.001
#
# [5 rows x 25 columns]

# %%
n_all_stars = len(df_stars)
n_stars = n_all_stars  # number of simulated stars to generate in the train and test sets
labels = ['teff', 'logg', 'fe_h', 'mg_h', 'n_h', 'si_h', 'ni_h', 'ca_h', 'ce_h']
photom = ['j-h', 'h-k']
n_labels = len(labels)  # number of labels to generate per star
n_photom = len(photom)
#n_latents = n_labels * 4  # size of the latent vector per star
n_latents = 20
n_flux = 2401  # number of spectral flux pixels per star

rng = np.random.default_rng(seed=8675309)

A = np.zeros((n_labels, n_latents))
A[0, 0] = 1.0
A[1, 1] = 1.0

B = rng.normal(scale=0.1, size=(n_flux, n_latents))
B[:, 0] = B[:, 0] + 4 * np.exp(-0.5 * (np.arange(n_flux) - n_flux / 2) ** 2 / 5**2)
B[:, 1] = B[:, 1] + 2 * np.exp(-0.5 * (np.arange(n_flux) - n_flux / 4) ** 2 / 3**2)

# %%
print("Number of all stars = ", len(df_stars))
df_stars = df_stars[:n_stars]
print("Number of stars in our set = ", len(df_stars))
df_stars.head(1)
# Out:
# Number of all stars =  500
# Number of stars in our set =  500
#              source_id                                               flux  \
# 0  4664665578195665280  [--, --, 0.9704861, 0.97988486, 0.97052944, 0....
#
#                                           flux_error         teff  e_teff  \
# 0  [--, --, 0.01576104, 0.00933747, 0.006561436, ...  4707.933105   3.487
#
#    logg  e_logg       j-h  e_j-h    h-k  ...   si_h    e_si_h   fe_h  e_fe_h  \
# 0  2.45   0.008  0.551001  0.025  0.068  ... -0.104  0.002236 -0.344   0.001
#
#     ni_h  e_ni_h   ca_h    e_ca_h   ce_h  e_ce_h
# 0 -0.185   0.001 -0.174  0.002236 -0.416   0.001
#
# [1 rows x 25 columns]

# %%
n_latents
# Out:
# 20

# %%
# List of error column names corresponding to labels
params_errors = [f"e_{p}" if not p.startswith('e_') else p for p in labels]
photom_errors = [f"e_{p}" if not p.startswith('e_') else p for p in photom]

# Stack columns for labels
df_stars_labels = np.column_stack([df_stars[p] for p in labels])
df_stars_photom = np.column_stack([df_stars[p] for p in photom])

# Stack columns for errors
df_stars_label_errs = np.column_stack([df_stars[e] for e in params_errors])
df_stars_photom_errs = np.column_stack([df_stars[e] for e in photom_errors])

df_stars_labels.shape
# Out:
# (500, 9)

# %%
df_stars = df_stars.reset_index(drop=True)

# %%
fluxes_with_ca_mask = []
flux_errs_with_ca_mask = []

lambdas = np.linspace(846, 870, 2401)

for i in range(len(df_stars['flux'])):
	flux_single,flux_err_single = process_spectra(lambdas,df_stars['flux'].iloc[i],df_stars['flux_error'].iloc[i])

	fluxes_with_ca_mask.append(flux_single)
	flux_errs_with_ca_mask.append(flux_err_single)

# %%
stars_dict = {
    'label': df_stars_labels,
    'label_err': df_stars_label_errs,
    'flux': fluxes_with_ca_mask,
    'flux_err': flux_errs_with_ca_mask,
    'photom': df_stars_photom,
    'photom_err': df_stars_photom_errs
}

# %%
flux, flux_err = process_spectra(lambdas, df_stars['flux'][0], df_stars['flux_error'][0])

flux

# %%
stars_dict['photom'][0]
# Out:
# array([0.5510006 , 0.06799984], dtype=float32)

# %%
stars_dict['flux'] = np.vstack([f.filled(1) if isinstance(f, np.ma.MaskedArray) else f
                              for f in stars_dict['flux']])

# Convert flux_err list to 2D array
stars_dict['flux_err'] = np.vstack([f.filled(9999) if isinstance(f, np.ma.MaskedArray) else f
                                  for f in stars_dict['flux_err']])

# %%
cmap = plt.get_cmap("coolwarm")
norm = mpl.colors.Normalize(
    vmin=stars_dict["label"][:, 0].min(), vmax=stars_dict["label"][:, 0].max()
)
fig, ax = plt.subplots(figsize=(8, 5), layout="constrained")

idx = np.argsort(stars_dict["label"][:, 0])
for i in np.linspace(0, len(idx) - 1, 16).astype(int):
    ax.plot(
        stars_dict["flux"][idx[i]],
        marker="",
        drawstyle="steps-mid",
        color=cmap(norm(stars_dict["label"][idx[i], 0])),
    )
ax.set(xlabel="pixel (wavelength)", ylabel="flux", title="Simulated spectra (flux)")

sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
cb = fig.colorbar(sm, ax=ax)
cb.set_label(f"{labels[0]}")

plt.show()

# %% [markdown]
# To use this data with the {py:class}`~pollux.models.LuxModel`, we will need to define a {py:class}`~pollux.data.PolluxData` instance. This object acts as a container for the data and uncertainties, and also provides a mechanism to define "pre-processors" for the data. In this case, we will define pre-processors that normalize the labels and spectra to have zero mean and unit variance:

# %%
'''
all_data = plx.data.PolluxData(
    flux=plx.data.OutputData(
        stars_dict["flux"],
        err=stars_dict["flux_err"],
        preprocessor=plx.data.ShiftScalePreprocessor.from_data(stars_dict["flux"]),
    ),
    label=plx.data.OutputData(
        stars_dict["label"],
        err=stars_dict["label_err"],
        preprocessor=plx.data.ShiftScalePreprocessor.from_data(stars_dict["label"]),
    ),
    photom=plx.data.OutputData(
        stars_dict["photom"],
        err=stars_dict["photom_err"],
        preprocessor=plx.data.ShiftScalePreprocessor.from_data(stars_dict["photom"]),
    )
)

'''

all_data = plx.data.PolluxData(
    flux=plx.data.OutputData(
        stars_dict["flux"],
        err=stars_dict["flux_err"],
        preprocessor=plx.data.ShiftScalePreprocessor.from_data(stars_dict["flux"]),
    ),
    label=plx.data.OutputData(
        stars_dict["label"],
        err=stars_dict["label_err"],
        preprocessor=plx.data.ShiftScalePreprocessor.from_data(stars_dict["label"]),
    )
)

preprocessed_data = all_data.preprocess()

# %%
train_data = preprocessed_data[: n_stars // 2]
test_data = preprocessed_data[n_stars // 2 :]
len(train_data), len(test_data)
# Out:
# (250, 250)

# %% [markdown]
# # Construct Lux model

# %%
model = plx.LuxModel(latent_size=n_latents)

# %%
print(all_data.keys())  # noqa: T201
model.register_output("label", LinearTransform(output_size=n_labels))
#model.register_output("photom", LinearTransform(output_size=n_photom))
model.register_output("flux", LinearTransform(output_size=n_flux))
# Out:
# dict_keys(['flux', 'label'])

# %%
rngs = jax.random.split(jax.random.PRNGKey(42), 3)

# For this demo, we'll generate outputs for 10 objects
latents = jax.random.normal(rngs[0], shape=(10, model.latent_size))
pars = {
    "label": {"A": jax.random.normal(rngs[1], shape=(n_labels, model.latent_size))},
    #"photom": {"A": jax.random.normal(rngs[1], shape=(n_photom, model.latent_size))},
    "flux": {"A": jax.random.normal(rngs[2], shape=(n_flux, model.latent_size))},
}
outputs = model.predict_outputs(latents, pars)
outputs["label"].shape, outputs["flux"].shape, #outputs["photom"].shape
# Out:
# ((10, 9), (10, 2401))

# %% [markdown]
# ## Optimizing the model with training data (i.e. training the model)

# %%
x = stars_dict['photom']

print("Total length:", len(x))
print("Number of zeros:", np.sum(x == 0))
print("Number of NaNs:", np.sum(np.isnan(x)))
print("Number of +inf:", np.sum(np.isposinf(x)))
print("Number of -inf:", np.sum(np.isneginf(x)))
print("Number of finite values:", np.sum(np.isfinite(x)))
# Out:
# Total length: 500
# Number of zeros: 0
# Number of NaNs: 0
# Number of +inf: 0
# Number of -inf: 0
# Number of finite values: 1000

# %%
plt.hist(stars_dict['photom_err'])
# Out:
# (array([[ 14., 130.,  98.,  74.,  83.,  60.,  16.,  17.,   7.,   1.],
#         [ 15., 132.,  91.,  76.,  86.,  59.,  16.,  17.,   7.,   1.]]),
#  array([0.005, 0.012, 0.019, 0.026, 0.033, 0.04 , 0.047, 0.054, 0.061,
#         0.068, 0.075]),
#  <a list of 2 BarContainer objects>)

# %%
opt_pars, svi_results = model.optimize(
    train_data,
    rng_key=jax.random.PRNGKey(112358),
    optimizer=numpyro.optim.Adam(1e-3),
    num_steps=10_000,
    svi_run_kwargs={"progress_bar": False},
)
svi_results.losses.block_until_ready()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 opt_pars, svi_results = model.optimize(
#       2     train_data,
#       3     rng_key=jax.random.PRNGKey(112358),
#       4     optimizer=numpyro.optim.Adam(1e-3),
#       5     num_steps=10_000,
#       6     svi_run_kwargs={"progress_bar": False},
#       7 )
#       8 svi_results.losses.block_until_ready()
#
#     [... skipping hidden 1 frame]
#
# File ~/Codes/LuxProject/pollux/src/pollux/models/lux.py:566, in Lux.optimize(self, data, num_steps, rng_key, optimizer, latents_prior, custom_model, fixed_pars, names, svi_run_kwargs)
#     564 guide = AutoDelta(model)
#     565 svi = SVI(model, guide, optimizer, Trace_ELBO())
# --> 566 svi_results = svi.run(svi_key, num_steps, data, **svi_run_kwargs)
#     567 packed_MAP_pars = guide.sample_posterior(sample_key, svi_results.params)
#     569 unpacked_pars = self.unpack_numpyro_pars(
#     570     packed_MAP_pars,
#     571     ignore_missing=bool(fixed_pars is not None or names is not None),
#     572 )
#
# File ~/miniconda3/envs/haniyeh_research/lib/python3.13/site-packages/numpyro/infer/svi.py:401, in SVI.run(self, rng_key, num_steps, progress_bar, stable_update, forward_mode_differentiation, init_state, init_params, *args, **kwargs)
#     398     return svi_state, loss
#     400 if init_state is None:
# --> 401     svi_state = self.init(rng_key, *args, init_params=init_params, **kwargs)
#     402 else:
#     403     svi_state = init_state
#
# File ~/miniconda3/envs/haniyeh_research/lib/python3.13/site-packages/numpyro/infer/svi.py:184, in SVI.init(self, rng_key, init_params, *args, **kwargs)
#     182 if init_params is not None:
#     183     guide_init = substitute(guide_init, init_params)
# --> 184 guide_trace = trace(guide_init).get_trace(*args, **kwargs, **self.static_kwargs)
#     185 init_guide_params = {
#     186     name: site["value"]
#     187     for name, site in guide_trace.items()
#     188     if site["type"] == "param"
#     189 }
#     190 if init_params is not None:
#
# File ~/miniconda3/envs/haniyeh_research/lib/python3.13/site-packages/numpyro/handlers.py:193, in trace.get_trace(self, *args, **kwargs)
#     185 def get_trace(self, *args, **kwargs) -> TraceT:
#     186     """
#     187     Run the wrapped callable and return the recorded trace.
#     188
#    (...)    191     :return: `OrderedDict` containing the execution trace.
#     192     """
# --> 193     self(*args, **kwargs)
#     194     return self.trace
#
# File ~/miniconda3/envs/haniyeh_research/lib/python3.13/site-packages/numpyro/primitives.py:119, in Messenger.__call__(self, *args, **kwargs)
#     117     return self
#     118 with self:
# --> 119     return self.fn(*args, **kwargs)
#
# File ~/miniconda3/envs/haniyeh_research/lib/python3.13/site-packages/numpyro/handlers.py:849, in seed.__call__(self, *args, **kwargs)
#     845     cloned_seeded_fn = seed(
#     846         self.fn, rng_seed=self.rng_key, hide_types=self.hide_types
#     847     )
#     848     cloned_seeded_fn.stateful = True
# --> 849     return cloned_seeded_fn.__call__(*args, **kwargs)
#     850 return super().__call__(*args, **kwargs)
#
# File ~/miniconda3/envs/haniyeh_research/lib/python3.13/site-packages/numpyro/handlers.py:850, in seed.__call__(self, *args, **kwargs)
#     848     cloned_seeded_fn.stateful = True
#     849     return cloned_seeded_fn.__call__(*args, **kwargs)
# --> 850 return super().__call__(*args, **kwargs)
#
# File ~/miniconda3/envs/haniyeh_research/lib/python3.13/site-packages/numpyro/primitives.py:119, in Messenger.__call__(self, *args, **kwargs)
#     117     return self
#     118 with self:
# --> 119     return self.fn(*args, **kwargs)
#
# File ~/miniconda3/envs/haniyeh_research/lib/python3.13/site-packages/numpyro/infer/autoguide.py:556, in AutoDelta.__call__(self, *args, **kwargs)
#     553 def __call__(self, *args, **kwargs):
#     554     if self.prototype_trace is None:
#     555         # run model to inspect the model structure
# --> 556         self._setup_prototype(*args, **kwargs)
#     558     plates = self._create_plates(*args, **kwargs)
#     559     result = {}
#
# File ~/miniconda3/envs/haniyeh_research/lib/python3.13/site-packages/numpyro/infer/autoguide.py:530, in AutoDelta._setup_prototype(self, *args, **kwargs)
#     529 def _setup_prototype(self, *args, **kwargs):
# --> 530     super()._setup_prototype(*args, **kwargs)
#     531     with numpyro.handlers.block():
#     532         self._init_locs = {
#     533             k: v
#     534             for k, v in self._postprocess_fn(self._init_locs).items()
#     535             if k in self._init_locs
#     536         }
#
# File ~/miniconda3/envs/haniyeh_research/lib/python3.13/site-packages/numpyro/infer/autoguide.py:160, in AutoGuide._setup_prototype(self, *args, **kwargs)
#     153 rng_key = numpyro.prng_key()
#     154 with handlers.block():
#     155     (
#     156         init_params,
#     157         self._potential_fn_gen,
#     158         postprocess_fn_gen,
#     159         self.prototype_trace,
# --> 160     ) = initialize_model(
#     161         rng_key,
#     162         self.model,
#     163         init_strategy=self.init_loc_fn,
#     164         dynamic_args=True,
#     165         model_args=args,
#     166         model_kwargs=kwargs,
#     167     )
#     168 self._potential_fn = self._potential_fn_gen(*args, **kwargs)
#     169 postprocess_fn = postprocess_fn_gen(*args, **kwargs)
#
# File ~/miniconda3/envs/haniyeh_research/lib/python3.13/site-packages/numpyro/infer/util.py:774, in initialize_model(rng_key, model, init_strategy, dynamic_args, model_args, model_kwargs, forward_mode_differentiation, validate_grad)
#     771 if device_get(~jnp.all(is_valid)):
#     772     with numpyro.validation_enabled(), trace() as tr:
#     773         # validate parameters
# --> 774         substituted_model(*model_args, **model_kwargs)
#     775         # validate values
#     776         for site in tr.values():
#
# File ~/miniconda3/envs/haniyeh_research/lib/python3.13/site-packages/numpyro/primitives.py:119, in Messenger.__call__(self, *args, **kwargs)
#     117     return self
#     118 with self:
# --> 119     return self.fn(*args, **kwargs)
#
# File ~/miniconda3/envs/haniyeh_research/lib/python3.13/site-packages/numpyro/handlers.py:849, in seed.__call__(self, *args, **kwargs)
#     845     cloned_seeded_fn = seed(
#     846         self.fn, rng_seed=self.rng_key, hide_types=self.hide_types
#     847     )
#     848     cloned_seeded_fn.stateful = True
# --> 849     return cloned_seeded_fn.__call__(*args, **kwargs)
#     850 return super().__call__(*args, **kwargs)
#
# File ~/miniconda3/envs/haniyeh_research/lib/python3.13/site-packages/numpyro/handlers.py:850, in seed.__call__(self, *args, **kwargs)
#     848     cloned_seeded_fn.stateful = True
#     849     return cloned_seeded_fn.__call__(*args, **kwargs)
# --> 850 return super().__call__(*args, **kwargs)
#
# File ~/miniconda3/envs/haniyeh_research/lib/python3.13/site-packages/numpyro/primitives.py:119, in Messenger.__call__(self, *args, **kwargs)
#     117     return self
#     118 with self:
# --> 119     return self.fn(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/Codes/LuxProject/pollux/src/pollux/models/lux.py:510, in Lux.default_numpyro_model(self, data, latents_prior, fixed_pars, names, custom_model)
#     504 with numpyro.handlers.condition(data=fixed_pars or {}):
#     505     latents = numpyro.sample(
#     506         "latents",
#     507         _latents_prior,
#     508         sample_shape=(n_data,),
#     509     )
# --> 510     pars = self.setup_numpyro(latents, data, names=names)
#     512 # Call the custom model function if provided
#     513 if custom_model is not None:
#
#     [... skipping hidden 1 frame]
#
# File ~/Codes/LuxProject/pollux/src/pollux/models/lux.py:440, in Lux.setup_numpyro(self, latents, data, names)
#     431     # TODO NOTE: failure mode where .err is None and the err_transform doesn't
#     432     # add a modeled intrinsic scatter. Detect this and raise an error?
#     433     # TODO: This interface could be made more general to support, e.g.,
#     434     # covariance matrices
#     435     err = self.outputs[output_name].err_transform.apply(
#     436         data[output_name].err, **err_pars[output_name]
#     437     )
#     438     numpyro.sample(
#     439         f"obs:{output_name}",
# --> 440         dist.Normal(pred, err),
#     441         obs=data[output_name].data,
#     442     )
#     444 for output_name in output_names:
#     445     data_pars[output_name].update(err_pars.get(output_name, {}))
#
# File ~/miniconda3/envs/haniyeh_research/lib/python3.13/site-packages/numpyro/distributions/distribution.py:104, in DistributionMeta.__call__(cls, *args, **kwargs)
#     102     if result is not None:
#     103         return result
# --> 104 return super().__call__(*args, **kwargs)
#
# File ~/miniconda3/envs/haniyeh_research/lib/python3.13/site-packages/numpyro/distributions/continuous.py:2379, in Normal.__init__(self, loc, scale, validate_args)
#    2377 self.loc, self.scale = promote_shapes(loc, scale)
#    2378 batch_shape = lax.broadcast_shapes(jnp.shape(loc), jnp.shape(scale))
# -> 2379 super(Normal, self).__init__(
#    2380     batch_shape=batch_shape, validate_args=validate_args
#    2381 )
#
# File ~/miniconda3/envs/haniyeh_research/lib/python3.13/site-packages/numpyro/distributions/distribution.py:246, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#     244     self._validate_args = validate_args
#     245 if self._validate_args:
# --> 246     self.validate_args(strict=False)
#     247 super(Distribution, self).__init__()
#
# File ~/miniconda3/envs/haniyeh_research/lib/python3.13/site-packages/numpyro/distributions/distribution.py:274, in Distribution.validate_args(self, strict)
#     272 if not_jax_tracer(is_valid):
#     273     if not np.all(is_valid):
# --> 274         raise ValueError(
#     275             "{} distribution got invalid {} parameter.".format(
#     276                 self.__class__.__name__, param
#     277             )
#     278         )
#     279 elif strict:
#     280     raise RuntimeError("Cannot validate arguments inside jitted code.")
#
# ValueError: Normal distribution got invalid scale parameter.

# %%
iterative_result = model.optimize_iterative(
    train_data,
    max_cycles=100,
    tol=1e-6,
    rng_key=jax.random.PRNGKey(112358),
    progress=False,
)

print(
    f"Converged: {iterative_result.converged} after {iterative_result.n_cycles} cycles"
)
# Out:
# Converged: False after 100 cycles

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4), layout="constrained")

# SVI loss trajectory
#axes[0].semilogy(svi_results.losses)
axes[0].set(xlabel="Step", ylabel="Loss", title="SVI Optimization")
'''
axes[0].axhline(
    svi_results.losses[-1],
    color="tab:orange",
    ls="--",
    label=f"Final: {svi_results.losses[-1]:.1f}",
)
axes[0].legend()
'''
# Iterative loss trajectory
axes[1].semilogy(iterative_result.losses_per_cycle)
axes[1].set(xlabel="Cycle", ylabel="Loss", title="Iterative Optimization")
axes[1].axhline(
    iterative_result.losses_per_cycle[-1],
    color="tab:orange",
    ls="--",
    label=f"Final: {iterative_result.losses_per_cycle[-1]:.1f}",
)
axes[1].legend()

plt.suptitle("Convergence Comparison", fontsize=14)
# Out:
# Text(0.5, 0.98, 'Convergence Comparison')

# %%
fig_xsize=12
fig_ysize=10

# %%
predict_train_values = model.predict_outputs(opt_pars["latents"], opt_pars)

pt_style = {"ls": "none", "ms": 2.0, "alpha": 0.5, "marker": "o", "color": "k"}

fig, axes = plt.subplots(3, 3, figsize=(fig_xsize, fig_ysize), layout="constrained")
axes = axes.flatten()
for i in range(predict_train_values["label"].shape[1]):
    axes[i].plot(
        predict_train_values["label"][:, i], train_data["label"].data[:, i], **pt_style
    )
    axes[i].set(xlabel=f"Predicted label {i} ({labels[i]})", ylabel=f"True label {i}")
    axes[i].axline([0, 0], slope=1, color="tab:green", zorder=-100)
_ = fig.suptitle("Training set: predicted vs. true labels", fontsize=22)

plt.show()

# %% [markdown]
# ## Optimize for latents for test set

# %%
fixed_pars = {
    "label": {"data": {"A": opt_pars["label"]["data"]["A"]}},
    "flux": {"data": {"A": opt_pars["flux"]["data"]["A"]}},
}

test_opt_pars, test_svi_results = model.optimize(
    test_data,
    rng_key=jax.random.PRNGKey(12345),
    optimizer=numpyro.optim.Adam(1e-3),
    num_steps=10_000,
    fixed_pars=fixed_pars,
    svi_run_kwargs={"progress_bar": False},
)
test_svi_results.losses.block_until_ready()
# Out:
# Array([4.76765348e+09, 4.72022877e+09, 4.67305431e+09, ...,
#        2.61659265e+06, 2.61652604e+06, 2.61645981e+06], dtype=float64)

# %%
predict_test_values = model.predict_outputs(test_opt_pars["latents"], fixed_pars)

# %%
fig, axes = plt.subplots(3, 3, figsize=(fig_xsize, fig_ysize), layout="constrained")
axes = axes.flatten()
for i in range(predict_test_values["label"].shape[1]):
    axes[i].plot(
        predict_test_values["label"][:, i], test_data["label"].data[:, i], **pt_style
    )
    axes[i].set_xlabel(f"Predicted label {i} ({labels[i]})", fontsize=20)
    axes[i].set_ylabel(f"True label {i}", fontsize=20)
    axes[i].axline([0, 0], slope=1, color="tab:green", zorder=-100)
_ = fig.suptitle("Test set: predicted vs. true labels", fontsize=22)

plt.show()

# %% [markdown]
# # with partial data (flux only)

# %%
flux_only_data = plx.data.PolluxData(flux=test_data["flux"])

# %%
test_opt_pars_flux, _ = model.optimize(
    flux_only_data,
    rng_key=jax.random.PRNGKey(12345),
    optimizer=numpyro.optim.Adam(1e-3),
    num_steps=10_000,
    fixed_pars=fixed_pars,
    names=["flux"],
    svi_run_kwargs={"progress_bar": False},
)

# %%
predict_test_values_flux = model.predict_outputs(
    test_opt_pars_flux["latents"], fixed_pars
)

# %%
fig, axes = plt.subplots(3, 3, figsize=(fig_xsize, fig_ysize), layout="constrained")
axes = axes.flatten()
for i in range(predict_test_values_flux["label"].shape[1]):
    axes[i].plot(
        predict_test_values_flux["label"][:, i], test_data["label"].data[:, i], **pt_style
    )
    axes[i].set_xlabel(f"Predicted label {i} ({labels[i]})", fontsize=20)
    axes[i].set_ylabel(f"True label {i}", fontsize=20)
    axes[i].axline([0, 0], slope=1, color="tab:green", zorder=-100)
_ = fig.suptitle(f"Flux only: predicted vs. true labels, giants, n_latents = {n_latents}", fontsize=22)

plt.show()

# %%
predict_test_values = model.predict_outputs(test_opt_pars["latents"], fixed_pars)
predict_test_unprocessed = test_data.unprocess(predict_test_values_flux)
test_data_unprocessed = all_data[n_stars // 2:]

# %%
fig, axes = plt.subplots(3, 3, figsize=(fig_xsize, fig_ysize), layout="constrained")
axes = axes.flatten()
for i in range(n_labels):
    axes[i].plot(
        predict_test_unprocessed["label"].data[:, i], test_data_unprocessed["label"].data[:, i], **pt_style
    )
    axes[i].set_xlabel(f"Predicted label {i} ({labels[i]})", fontsize=20)
    axes[i].set_ylabel(f"True label {i}", fontsize=20)
    axes[i].axline([0, 0], slope=1, color="tab:green", zorder=-100)
_ = fig.suptitle(f"Test set: predicted vs. true labels, n_latents = {n_latents}", fontsize=22)
plt.show()

# %%
results = {}

for i, name in enumerate(labels):
    y_true = test_data_unprocessed["label"].data[:, i]
    y_pred = predict_test_unprocessed["label"].data[:, i]

    res = y_pred - y_true

    results[name] = {
        "y_true": y_true,
        "y_pred": y_pred,
        "residuals": res,
        "std_res": np.std(res),
        "RMSE": np.sqrt(np.mean(res**2)),
        "MAE": np.mean(np.abs(res)),
        "Bias": np.mean(res),
        "R2": 1 - np.sum(res**2) / np.sum((y_true - np.mean(y_true))**2),
    }

# %%
plt.figure(figsize=(18,10))

for i in range(len(labels)):
    name = labels[i]
    plt.subplot(3,3,i+1)
    plt.scatter(results[name]["y_true"], results[name]["residuals"], s = 3)
    plt.axhline(0, color="k")
    plt.xlabel(f"True {name}")
    plt.ylabel("Residual")
    plt.title(f"RMSE = {results[name]["RMSE"]:.2f}, R2 = {results[name]["R2"]:.2f}")

plt.suptitle(f"giants, n_latents = {n_latents}")
plt.tight_layout()
